# %%
! pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 508 kB 11.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 18.5 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd 
import numpy as np

# %%
# pd.Series() - 1D data with an index

resturant_Data = {
    'Table_No' : [12,14,15],
    'Bill_Amount':[1250,890,2400],
    'Waiter_Name':['Amit','Priya','Rahul']
} 

df = pd.DataFrame(resturant_Data)

# print(df)

# Table_No  Bill_Amount Waiter_Name
# 0        12         1250        Amit
# 1        14          890       Priya
# 2        15         2400       Rahul


# print(type(df))
# <class 'pandas.core.frame.DataFrame'>


# print(df['Bill_Amount'])

# 0    1250
# 1     890
# 2    2400
# Name: Bill_Amount, dtype: int64


# print(type(df['Bill_Amount']))

# <class 'pandas.core.series.Series'>


#>>>>>>>> SERIES<<<<<<<<<#

total_bill = [4700,8000,1200,500]

s=pd.Series(total_bill,index=['mon','tue','wed','fri'])

print(s)
print(type(s))
# Out:
# mon    4700
# tue    8000
# wed    1200
# fri     500
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#.values

print(df.values)
print(type(df.values))
# Out:
# [[12 1250 'Amit']
#  [14 890 'Priya']
#  [15 2400 'Rahul']]
# <class 'numpy.ndarray'>

# %%
items = [45,30,15,60]

s=pd.Series(items,index=('Pizza','Burger','Pasta','Fries'))
print(s)
# Out:
# Pizza     45
# Burger    30
# Pasta     15
# Fries     60
# dtype: int64

# %%
Stock_Data = {
    'Brand':['Nike','Puma','Adidas','rebook'],
    ''

}

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/Users/prachipradhan/Desktop/MACHINE_LEARNING/Pandas/tip.csv")
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.tail(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# ...

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 120       11.69  2.31    Male     No  Thur   Lunch     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2

# %%
df.shape

#gives no of rows and colouns 

# df.columns

# df.columns[1]

df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print(df['day'].value_counts())
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
print(df['day'].unique())
# Out:
# ['Sun' 'Sat' 'Thur' 'Fri']

# %%
print(df['day'].ununique())

# titanic dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mn/8dpyy34d0dn8blqzy3hc6scw0000gn/T/ipykernel_3103/2569250788.py in ?()
# ----> 1 print(df['day'].ununique())
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'ununique'

# %%
import pandas as pd 
import numpy as np

df=pd.read_csv("/Users/prachipradhan/Desktop/MACHINE_LEARNING/Pandas/tip.csv")
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
x =df['day']

print(x.shape)

y = df['']
print(x)
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object
